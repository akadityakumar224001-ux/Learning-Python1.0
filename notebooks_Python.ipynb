# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ## NoteBook

# %% [markdown]
# # simple - programming language

# %%
print(1)
# Out:
# 1

# %% [markdown]
# ## Variables

# %%
name = "I'm learning python"

# %%
x = 5

# %%
y = True

# %%
z = 1.5

# %%
print(name,x,y,z,4,6)
# Out:
# I'm learning python 5 True 1.5 4 6

# %%
type(z)
# Out:
# float

# %% [markdown]
# ## Question time

# %%
num1 = 10

# %%
num2 = 20

# %%
print(num1+num2)
# Out:
# 30

# %%
name = "Aarav"

# %%
"My name is Aarav"
# Out:
# 'My name is Aarav'

# %%
print("My name is",name)
# Out:
# My name is Aarav

# %%
length = 500045453

# %%
width = 7676878734

# %%
area = length*width
print(area)
# Out:
# 3838788304169096502

# %%
"shift+enter"
# Out:
# 'shift+enter'

# %%
a = 10

# %%
b = a

# %%
a = 20

# %%
print(a,b)
# Out:
# 20 10

# %%
x,y,z=1,2,3

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
z
# Out:
# 3

# %%
x = 'A'

# %%
print(x)
# Out:
# A

# %%
x = x+'a'

# %%
print(x)
# Out:
# Aa

# %%
x = x+'B'

# %%
print(x)
# Out:
# AaB

# %% [markdown]
# #### Next tricky question

# %%
x = 5
y = 10

# %%
x = y

# %%
y = 20

# %%
print(x)
print(y)
# Out:
# 10
# 20

# %%
'100% correct'
# Out:
# '100% correct'

# %%
# comment

# %%
# we are learning variables

# %%
"""This is a multiline comment using triple double quotes
It will be ignored by Python if not assigned to any variable
"""
# Out:
# 'This is a multiline comment using triple double quotes\nIt will be ignored by Python if not assigned to any variable\n'

# %%
# I'm learning python
#declear x
x = 5
# declear y
y = 7

# %%
2name = "python"
# Out:
#   Cell In[101], line 1
#     2name = "python"
#     ^
# SyntaxError: invalid decimal literal

# %%
_name = "python"

# %%
name = "a"

# %%
name2 = "ab"

# %%
3.5name = "v"
# Out:
#   Cell In[106], line 1
#     3.5name = "v"
#       ^
# SyntaxError: invalid decimal literal

# %%
name = "X"
Name = "Y"

# %%
print(name)
# Out:
# X

# %%
naMe = "z"

# %%
namE = "p"

# %%
print(name,Name,naMe,namE)
# Out:
# X Y z p

# %% [markdown]
# # Day 2

# %% [markdown]
# ## data structures

# %%
name = "aditya"
salary_aditya = 20000
name_2 = "abhinav-CO"

# %% [markdown]
# # 1. list - list can store mutiple values

# %%
Employees_company = ["Pragya","Aarav","Aditya","Abhinav","Ruby","Zoya","Mark","Abhinash","B","C"]

# %%
print(Employees_company)
# Out:
# ['Pragya', 'Aarav', 'Aditya', 'Abhinav', 'Ruby', 'Zoya', 'Mark', 'Abhinash', 'B', 'C']

# %%
"""
Excel - data - employee name + salary
Read excel file - read employee name + salary - Employees_company , Salary_company
"""
# Out:
# '\nExcel - data - employee name + salary\nRead excel file - read employee name + salary - Employees_company , Salary_company\n'

# %%
Employees_company[0]
# Out:
# 'Pragya'

# %%
# In python - Index starts from 0

# %%
Employees_company[1]
# Out:
# 'Aarav'

# %%
#New employee - xu Lin

# %%
# Append
Employees_company.append("Xu Lin")

# %%
Employees_company
# Out:
# ['Pragya',
#  'Aarav',
#  'Aditya',
#  'Abhinav',
#  'Ruby',
#  'Zoya',
#  'Mark',
#  'Abhinash',
#  'B',
#  'C',
#  'Xu Lin']

# %%
Employees_company.index("Xu Lin")
# Out:
# 10

# %%
Employees_company[10]
# Out:
# 'Xu Lin'

# %%
Employees_company.pop()
# Out:
# 'Xu Lin'

# %%
Employees_company
# Out:
# ['Pragya',
#  'Aarav',
#  'Aditya',
#  'Abhinav',
#  'Ruby',
#  'Zoya',
#  'Mark',
#  'Abhinash',
#  'B',
#  'C']

# %%
Employees_company.pop()
# Out:
# 'C'

# %%
Employees_company
# Out:
# ['Pragya',
#  'Aarav',
#  'Aditya',
#  'Abhinav',
#  'Ruby',
#  'Zoya',
#  'Mark',
#  'Abhinash',
#  'B']

# %%
Employees_company.remove("Aarav")

# %%
Employees_company
# Out:
# ['Pragya', 'Aditya', 'Abhinav', 'Ruby', 'Zoya', 'Mark', 'Abhinash', 'B']

# %%
Employees_company.remove(1) - wrong
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 Employees_company.remove(1)
#
# ValueError: list.remove(x): x not in list

# %%
Employees_company.pop(2)
# Out:
# 'Abhinav'

# %%
Employees_company
# Out:
# ['Pragya', 'Aditya', 'Ruby', 'Zoya', 'Mark', 'Abhinash', 'B']

# %%
# XYZ - append on 1st index
Employees_company.insert(1,"XYZ")

# %%
Employees_company
# Out:
# ['Pragya', 'XYZ', 'Aditya', 'Ruby', 'Zoya', 'Mark', 'Abhinash', 'B']

# %%
Employees_company.insert(1,"Aarav")

# %%
Employees_company
# Out:
# ['Pragya', 'Aarav', 'XYZ', 'Aditya', 'Ruby', 'Zoya', 'Mark', 'Abhinash', 'B']

# %%
Employees_company.clear()

# %%
Employees_company
# Out:
# []

# %%
A,B,C

# %%
Employees_company.sort()

# %%
Employees_company
# Out:
# ['Pragya',
#  'Aarav',
#  'Aditya',
#  'Abhinav',
#  'Ruby',
#  'Zoya',
#  'Mark',
#  'Abhinash',
#  'B',
#  'C']

# %%
Employees_company.reverse()

# %%
Employees_company
# Out:
# ['C',
#  'B',
#  'Abhinash',
#  'Mark',
#  'Zoya',
#  'Ruby',
#  'Abhinav',
#  'Aditya',
#  'Aarav',
#  'Pragya']

# %% [markdown]
# ## Questions - list

# %%
#First element access- 
Employees_company[0]
# Out:
# 'Pragya'

# %%
Employees_company.reverse()

# %%
Employees_company[0]
# Out:
# 'C'

# %%
Employees_company[-1]
# Out:
# 'C'

# %%
a = [5,7,9]

# %%
b = a

# %%
a.append(b)

# %%
a
# Out:
# [5, 7, 9, [...]]

# %%
a[3][0]
# Out:
# 5

# %%
mix = ["ad",2,"yx",7,True,9.7]

# %%
mix
# Out:
# ['ad', 2, 'yx', 7, True, 9.7]

# %%
pie = 3.14714

# %%
pie = [3.14712,3.1492]

# %%
numbers = [3,6,9, [1,2,3]]

# %%
numbers[-1][-1]
# Out:
# 3

# %%
numbers2 = [
# Out:
# Hello worldgghghg

# %%
"ctrl+z"
# Out:
# 'ctrl+z'

# %% [markdown]
# ## 20 Python List Questions
#
# 1. What is a list in Python?
# 2. How do you create an empty list?
# 3. How do you add an item to the end of a list?
# 4. How do you access the first element of a list?
# 5. How do you find the length of a list?
# 6. What is the difference between append() and extend()?
# 7. How do you remove the last item from a list?
# 8. How do you sort a list in ascending order?
# 9. How do you reverse a list?
# 10. How do you copy a list without changing the original?
# 11. What will happen if you do list1 = list2 and then change list1?
# 12. What is the output of [1, 2, 3] + [4]?
# 13. What is the difference between list[0] and list[:1]?
# 14. How do you check whether an item exists in a list?
# 15. What happens if you try to access an index that does not exist?
# 16. How do you remove a specific item by value from a list?
# 17. What is the result of [1, 2, 3] * 2?
# 18. Why does list1 = list2 not create two independent lists?
# 19. What is the difference between pop() and remove()?
# 20. How can you get the last element of a list without using negative indexing?
